# %%
# !pip install ultralytics
# !pip install roboflow
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 644.7/644.7 kB 8.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.8/58.8 kB 1.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 155.3/155.3 kB 7.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 178.7/178.7 kB 20.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.8/58.8 kB 7.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.1/49.1 MB 15.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.8/67.8 kB 7.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 72.2/72.2 kB 8.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.5/54.5 kB 6.6 MB/s eta 0:00:00
# ...
#   Attempting uninstall: pyparsing
#     Found existing installation: pyparsing 3.1.1
#     Uninstalling pyparsing-3.1.1:
#       Successfully uninstalled pyparsing-3.1.1
#   Attempting uninstall: opencv-python-headless
# ...

# %%
import ultralytics
from roboflow import Roboflow
from ultralytics import YOLO
from IPython.display import Image

# %%
rf = Roboflow(api_key="hsQdpSrCdgURcot4CSDL")
project = rf.workspace("staj-dskrn").project("insantespit")
dataset = project.version(1).download("yolov8")

# %%
# !yolo task=detect mode=train model=yolov8s.pt data=/content/insanTespit-1/custom.yaml epochs=25 imgsz=230 plots=True,
# Out:
# WARNING ⚠️ 'plots=True,' does not require trailing comma ',', updating to 'plots=True'.
# Ultralytics YOLOv8.0.201 🚀 Python-3.10.12 torch-2.1.0+cu118 CPU (Intel Xeon 2.20GHz)
# ...

# %%
# !yolo task=detect mode=predict model=/content/runs/detect/train3/weights/best.pt conf=0.25 source=/content/insanTespit-1/test/images save=True
# Out:
# Ultralytics YOLOv8.0.201 🚀 Python-3.10.12 torch-2.1.0+cu118 CPU (Intel Xeon 2.20GHz)
# Model summary (fused): 168 layers, 11125971 parameters, 0 gradients, 28.4 GFLOPs
#
# image 1/55 /content/insanTespit-1/test/images/100_png.rf.f84dc4b653282162d4600afa9832d5c6.jpg: 256x256 1 insan, 171.8ms
# image 2/55 /content/insanTespit-1/test/images/110_png.rf.1521ba05b655a112e3909a9868d4fcb3.jpg: 256x256 2 insans, 121.9ms
# image 3/55 /content/insanTespit-1/test/images/114_png.rf.e16c41ef98be21c84b8b3a369d8c8142.jpg: 256x256 2 insans, 98.2ms
# image 4/55 /content/insanTespit-1/test/images/118_png.rf.38dfdfe6a703804695059c8d54186af6.jpg: 256x256 2 insans, 103.2ms
# image 5/55 /content/insanTespit-1/test/images/128_png.rf.61e52282bb32604884d5b04c1d876db2.jpg: 256x256 2 insans, 111.3ms
# image 6/55 /content/insanTespit-1/test/images/147_png.rf.dc2a99a3c5d7e95834ece903ee81bc5e.jpg: 256x256 2 insans, 98.6ms
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import shutil
import os

# Hedef dizini silme (Google Drive'daki hedef dizinini siler)
if os.path.exists(target_directory):
    shutil.rmtree(target_directory)

# Yeni hedef dizinini oluşturun
os.makedirs(target_directory, exist_ok=True)

# Dizinleri kopyalama
shutil.copytree(source_directory, target_directory)
# Out:
# ---------------------------------------------------------------------------
# FileExistsError                           Traceback (most recent call last)
# <ipython-input-23-352373a5733c> in <cell line: 12>()
#      10
#      11 # Dizinleri kopyalama
# ---> 12 shutil.copytree(source_directory, target_directory)
#      13
#
# /usr/lib/python3.10/shutil.py in copytree(src, dst, symlinks, ignore, copy_function, ignore_dangling_symlinks, dirs_exist_ok)
#     557     with os.scandir(src) as itr:
#     558         entries = list(itr)
# --> 559     return _copytree(entries=entries, src=src, dst=dst, symlinks=symlinks,
#     560                      ignore=ignore, copy_function=copy_function,
#     561                      ignore_dangling_symlinks=ignore_dangling_symlinks,
#
# /usr/lib/python3.10/shutil.py in _copytree(entries, src, dst, symlinks, ignore, copy_function, ignore_dangling_symlinks, dirs_exist_ok)
#     455         ignored_names = set()
#     456
# ...
